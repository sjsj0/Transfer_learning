# %%
import numpy as np
import cv2

import PIL.Image as Image
import os

import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
IMAGE_SHAPE = (224, 224)

classifier = tf.keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4", input_shape=IMAGE_SHAPE+(3,))
])

# %%
IMAGE_SHAPE+(3,)
# Out:
# (224, 224, 3)

# %% [markdown]
# # CASE 1

# %% [markdown]
# #### first classify that class which is already available..

# %%
gold_fish = Image.open("goldfish.jpg").resize(IMAGE_SHAPE)
gold_fish
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1E8BB0A7EB0>

# %% [markdown]
# #### before classification lets scale or normalize the image..

# %%
gold_fish = np.array(gold_fish)/255.0
gold_fish.shape
# Out:
# (224, 224, 3)

# %%
# np.set_printoptions(suppress = True)
gold_fish
# Out:
# array([[[0.28235294, 0.33333333, 0.07058824],
#         [0.31372549, 0.37254902, 0.09019608],
#         [0.34901961, 0.41960784, 0.11764706],
#         ...,
#         [0.32941176, 0.39215686, 0.00392157],
#         [0.32156863, 0.38431373, 0.00392157],
#         [0.30980392, 0.36862745, 0.        ]],
#
#        [[0.28627451, 0.33333333, 0.08235294],
#         [0.3254902 , 0.38039216, 0.10980392],
#         [0.35294118, 0.42352941, 0.12941176],
#         ...,
#         [0.32156863, 0.38039216, 0.00392157],
#         [0.31372549, 0.37254902, 0.00392157],
#         [0.30196078, 0.36078431, 0.        ]],
#
#        [[0.28627451, 0.33333333, 0.08627451],
#         [0.31372549, 0.36862745, 0.10196078],
#         [0.34509804, 0.41568627, 0.12941176],
#         ...,
#         [0.31764706, 0.37647059, 0.00392157],
#         [0.30980392, 0.36862745, 0.00784314],
#         [0.29803922, 0.35686275, 0.00392157]],
#
#        ...,
#
#        [[0.05490196, 0.10980392, 0.01568627],
# ...

# %% [markdown]
# #### to make predictions it should add a new dimension.. as we are only giving single image.

# %%
gold_fish[np.newaxis,...].shape
# Out:
# (1, 224, 224, 3)

# %%
result = classifier.predict(gold_fish[np.newaxis,...])
result.shape
# Out:
# (1, 1001)

# %%
predicted_index = np.argmax(result)
predicted_index
# Out:
# 2

# %%
# tf.keras.utils.get_file('ImageNetLabels.txt','https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt')

# %%
labels = []
with open("classes.txt","r") as f:
    labels = f.read().splitlines()
labels[:5]
# Out:
# ['background', 'tench', 'goldfish', 'great white shark', 'tiger shark']

# %%
labels[predicted_index]
# Out:
# 'goldfish'

# %% [markdown]
# #### try again with some other random image of goldfish..

# %%
gold2 = Image.open("gold2.jpg").resize(IMAGE_SHAPE)
gold2= np.array(gold2)/255.0
result = classifier.predict(gold2[np.newaxis,...])
predicted_index = np.argmax(result)
labels[predicted_index]
# Out:
# 'goldfish'

# %% [markdown]
# # CASE 2

# %% [markdown]
# #### now classify the class which is not available...lets say take some flowers..

# %%
# dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
# data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)
# Out:
# ...
# 228818944/228813984 [==============================] - 66s 0us/step

# %%
data_dir
# Out:
# '.\\datasets\\flower_photos'

# %%
import pathlib
data_dir = pathlib.Path(data_dir)
data_dir
# Out:
# WindowsPath('datasets/flower_photos')

# %%
list(data_dir.glob("*/*.jpg"))[:5]
# Out:
# [WindowsPath('datasets/flower_photos/daisy/100080576_f52e8ee070_n.jpg'),
#  WindowsPath('datasets/flower_photos/daisy/10140303196_b88d3d6cec.jpg'),
#  WindowsPath('datasets/flower_photos/daisy/10172379554_b296050f82_n.jpg'),
#  WindowsPath('datasets/flower_photos/daisy/10172567486_2748826a8b.jpg'),
#  WindowsPath('datasets/flower_photos/daisy/10172636503_21bededa75_n.jpg')]

# %%
img_count = len(list(data_dir.glob("*/*.jpg")))
img_count
# Out:
# 3670

# %%
roses = list(data_dir.glob("roses/*.jpg"))
roses[:5]
# Out:
# [WindowsPath('datasets/flower_photos/roses/10090824183_d02c613f10_m.jpg'),
#  WindowsPath('datasets/flower_photos/roses/102501987_3cdb8e5394_n.jpg'),
#  WindowsPath('datasets/flower_photos/roses/10503217854_e66a804309.jpg'),
#  WindowsPath('datasets/flower_photos/roses/10894627425_ec76bbc757_n.jpg'),
#  WindowsPath('datasets/flower_photos/roses/110472418_87b6a3aa98_m.jpg')]

# %%
Image.open(roses[1])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x1E8C9E69940>

# %% [markdown]
# #### storing all the paths in the dictionary...

# %%
flowers_images_dict = {
    'roses': list(data_dir.glob('roses/*')),
    'daisy': list(data_dir.glob('daisy/*')),
    'dandelion': list(data_dir.glob('dandelion/*')),
    'sunflowers': list(data_dir.glob('sunflowers/*')),
    'tulips': list(data_dir.glob('tulips/*')),
}

# %%
flowers_labels_dict = {
    'roses': 0,
    'daisy': 1,
    'dandelion': 2,
    'sunflowers': 3,
    'tulips': 4,
}

# %%
img = cv2.imread(str(flowers_images_dict['roses'][0]))
img.shape
# Out:
# (240, 179, 3)

# %%
cv2.resize(img,IMAGE_SHAPE).shape
# Out:
# (224, 224, 3)

# %%
X, y = [], []

for flower_name, images in flowers_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img, IMAGE_SHAPE)
        X.append(resized_img)
        y.append(flowers_labels_dict[flower_name])

# %%
X = np.array(X)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_train = X_train/255
X_test = X_test/255
